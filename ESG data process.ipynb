# %%
import pandas as pd

# %%
# read bloomberg excel with company
df=pd.read_excel('ESG data/Hardware Gov.xlsx')
display(df)
#df['Unnamed: 1'] = df['Unnamed: 1'].str.replace(' US Equity', '', regex=False)
df = df[df['Ticker'].str.endswith("US Equity")]
df['Ticker'] = df['Ticker'].str.replace(r' \b\w{2} Equity\b', '', regex=True)
display(df)
df.to_excel("ESG data/Hardware Gov.xlsx", index=False)
# Out:
#                   Security_Name          Ticker  \
# 0               3D Systems Corp   DDD US Equity
# 1              A10 Networks Inc  ATEN US Equity
# 2           ADTRAN Holdings Inc  ADTN US Equity
# 3       ARRIS International Ltd  ARRS US Equity
# 4     Akoustis Technologies Inc  AKTS US Equity
# ..                          ...             ...
# 103        Western Digital Corp   WDC US Equity
# 104  Wireless Telecom Group Inc   WTT US Equity
# 105         Xerox Holdings Corp   XRX US Equity
# 106     Zebra Technologies Corp  ZBRA US Equity
# 107                 voxeljet AG  VJET US Equity
#
#                                              Bi074        Country      2022  \
# 0    Technology Hardware, Equipment and Components  United States       NaN
# 1    Technology Hardware, Equipment and Components  United States  7.009985
# 2    Technology Hardware, Equipment and Components  United States       NaN
# 3    Technology Hardware, Equipment and Components  United States       NaN
# ...
